# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
Kr = 69.95526
Br = 69.9446160
Se = 69.93339
As = 69.93093
Ge = 69.924249
Ga = 69.9260220
Zn = 69.925319
Cu = 69.9323923
Ni = 69.93650
Co = 69.9510

# %%
masses = np.array([Kr,Br,Se,As,Ge,Ga,Zn,Cu,Ni,Co])
z_nums = np.array([36,35,34,33,32,31,30,29,28,27])

# %%
plt.plot(z_nums, masses)

# %%
aa = 23.20 #MeV
ac = .714 #MeV

mnc2 = 9.39565346e3 #MeV
mpc2 = 9.38272013e3 #MeV

A = 70 #Nucleons

Z = (A/2) * (1 + (mnc2-mpc2)/(4*aa)) / (1 + ac*A**(2/3)/(4*aa))
Z
# Out:
# 35.26886797800887
